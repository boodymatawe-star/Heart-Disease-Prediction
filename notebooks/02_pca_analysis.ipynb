# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
# load the x and y from preprocessing
X_scaled = np.load("X_scaled.npy")
Y = np.load("y.npy")
#apply the PCA
pca=PCA()
pca_full=pca.fit_transform(X_scaled)
#explained variance
explained_variance = np.cumsum(pca.explained_variance_ratio_)
print(explained_variance)
# Out:
# [0.16980488 0.29531658 0.39923009 0.48286729 0.56022573 0.63460194
#  0.70054562 0.76008045 0.81671687 0.86750882 0.90984125 0.94008086
#  0.96792791 0.99077397 1.        ]

# %%
# Visualize
plt.plot(range(1,len(explained_variance)+1),explained_variance,marker='o')
plt.xlabel('number of components')
plt.ylabel('Explained variance')
plt.title('cumulative variance plot')
plt.grid()
plt.show()

# %%
plt.scatter(pca_full[:, 0],pca_full[:, 1], c=Y, cmap='viridis')
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA Scatter Plot (first 2 components)")
plt.colorbar(label='Target (num)')
plt.show()
